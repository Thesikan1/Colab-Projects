# %%
#getting an image using web get
# !wget 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcToUzXImsyOgwZSOJ__coUTpD-Kj0DnNrbZUw&s'
# Out:
# --2025-03-11 12:48:33--  https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcToUzXImsyOgwZSOJ__coUTpD-Kj0DnNrbZUw&s
# Resolving encrypted-tbn0.gstatic.com (encrypted-tbn0.gstatic.com)... 108.177.11.102, 108.177.11.100, 108.177.11.101, ...
# Connecting to encrypted-tbn0.gstatic.com (encrypted-tbn0.gstatic.com)|108.177.11.102|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5575 (5.4K) [image/jpeg]
# Saving to: ‘images?q=tbn:ANd9GcToUzXImsyOgwZSOJ__coUTpD-Kj0DnNrbZUw&s’
#
# images?q=tbn:ANd9Gc 100%[===================>]   5.44K  --.-KB/s    in 0s
#
# 2025-03-11 12:48:33 (24.8 MB/s) - ‘images?q=tbn:ANd9GcToUzXImsyOgwZSOJ__coUTpD-Kj0DnNrbZUw&s’ saved [5575/5575]

# %% [markdown]
# Libraries that can be used for image processing
#
#
# 1.   matplotlib.image
# 2.   pillow
# 3.   openCV(cv2)

# %%
#importing the image module from matplotlib library
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
#loading an image through.image module
img=mpimg.imread('/content/Dog.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
# Out:
# (187, 270, 3)

# %%
print(img)
# Out:
# [[[226 229 236]
#   [226 229 236]
#   [226 229 236]
#   ...
#   [164 164 156]
#   [160 160 152]
#   [157 157 149]]
#
#  [[226 229 236]
#   [226 229 236]
#   [226 229 236]
#   ...
#   [157 157 149]
#   [153 153 145]
#   [150 150 142]]
#
#  [[225 228 235]
#   [225 228 235]
#   [225 228 235]
#   ...
#   [150 147 138]
#   [146 143 134]
#   [143 140 131]]
#
#  ...
#
#  [[131 125  65]
#   [129 125  64]
#   [127 123  62]
#   ...
#   [101  96  38]
#   [ 96  91  35]
#   [ 93  88  32]]
#
#  [[129 125  64]
#   [128 124  63]
#   [126 122  61]
#   ...
#   [101  96  40]
#   [ 96  91  35]
#   [ 93  88  32]]
#
#  [[127 125  64]
#   [126 124  63]
#   [124 122  61]
#   ...
#   [101  96  41]
#   [ 94  91  36]
#   [ 91  88  33]]]

# %%
# displaying the image from numpy array
img_plot=plt.imshow(img)
plt.show()

# %% [markdown]
# Resizing the image using pillow library

# %%
from PIL import Image

# %%
img=Image.open('/content/Dog.jpg')
img_resized=img.resize((200,200))

# %%
img_resized.save('dog_image_resized.jpg')

# %%
#displaying the image from numpy array
img_res=mpimg.imread('/content/dog_image_resized.jpg')
img_res_plot=plt.imshow(img_res)
plt.show()

# %%
print(img_res.shape)
# Out:
# (200, 200, 3)

# %% [markdown]
# converting RGB images to grayscale image using opencv

# %%
#importing opencv library
import cv2

# %%
img=cv2.imread('/content/Dog.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (187, 270, 3)

# %%
grayscale_image=cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
grayscale_image.shape
# Out:
# (187, 270)

# %% [markdown]
# cv2.imshow() will display the image.But this will not be allowed in google colab
#
# **from google.colab.patches import cv2_imshow**

# %%
from google.colab.patches import cv2_imshow

# %%
#displaying the image
cv2_imshow(grayscale_image)
# Out:
# <PIL.Image.Image image mode=L size=270x187>

# %%
#saving the grayscale image
cv2.imwrite('grayscale_image.jpg',grayscale_image)
# Out:
# True
